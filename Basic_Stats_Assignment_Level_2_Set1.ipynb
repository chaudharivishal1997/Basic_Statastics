# %%
import pandas as pd
import numpy as np
import scipy
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Look at the data given below. Plot the data, find the outliers and find out 𝜇, 𝜎, 𝜎2
# ![image.png](attachment:image.png)

# %%
x=pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])
names=['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers',
      'Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems','Travelers','US Airways',
      'Warner-Lambert']

# %%
#Plotting PiePlot
plt.figure(figsize=(6,6))
plt.pie(x,labels=names,autopct='%.f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Plotting Boxplot to find Outliers
sns.boxplot(x)
# Out:
# C:\Users\chaud\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
print('μ ',x.mean())
print('σ = ',x.var())
print('σ**2 = ',x.std())
# Out:
# μ  33.27133333333333
# σ =  287.1466123809524
# σ**2 =  16.945400921222028

# %%
Profit=pd.Series([0.1,0.1,0.2,0.2,0.3,0.1])
print('Standard Deviation = ',Profit.std())
# Out:
# Standard Deviation =  0.0816496580927726
